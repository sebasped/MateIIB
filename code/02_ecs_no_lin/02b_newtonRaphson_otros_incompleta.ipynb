# %% [markdown]
# # Librerías

# %%
import numpy as np #para manejar arreglos
from matplotlib import pyplot as plt #para graficar

plt.rcParams["figure.figsize"] = (10,7) #tamaño de los gráficos: ancho x alto

# %% [markdown]
# # Método de Newton-Raphson: ¿cuál es la idea y objetivo de este método?
# ---

# %% [markdown]
# ## Definir `metodo_newtonRaphson_tol` que aplique el método de Newton-Raphson la cantidad de veces _necesaria_ hasta que $|x_{n+1} - x_n| < ϵ$, donde $ϵ$  es la tolerancia y es típicamente un número chico.
#
# ---
#
# ## Idea igual que antes:
# ### **Primero** definir `paso_newtonRaphson` que haga **UN SOLO PASO** de Newton-Raphson
# ### ¿Qué tiene que recibir como entrada esta función? ¿Qué tiene que devolver?
#
#
# ### **Segundo** definir `metodo_newtonRaphson_tol`.
# ### ¿Qué tiene que recibir como entrada esta función? ¿Qué tiene que devolver?

# %%
def paso_newtonRaphson(...):
# completar
  return ...

def metodo_newtonRaphson_tol(...):
# completar
  return

# %% [markdown]
# ### Testeamos  `metodo_newtonRaphson_tol` para aproximar una solución de $x^2-2=0$.

# %%
# Testeamos Newton_Raphson con un ejemplo sencillo

def f(x):
# completar

def df(x):
# completar

x_inic = 5 #experimentar variando
tolerancia = 10**(-5)  #experimentar variando

x_final = # completar
# print("La aproximación con toletancia", tolerancia, "es:", x_final )
# print("El valor exacto es:", 2**(1/2))
# print("¿Qué error estoy cometiendo?")
# print("¿Cuántos pasos en total se dieron?")
# print("¿Necesité más o menos pasos que en bisección para la misma tolerancia")

# %% [markdown]
# ---
# # **Ejercicio:** el 6 de la P2.
#
# # **Ejercicio:** el 10 de la P2 (implementar el método de la Secante y aplicar a un ejemplo).
#
# # **Ejercicio:** implementar la versión del método de Newton-Raphson con cantidad de pasos (antes hicimos con tolerancia).
#
# # **Ejercicio:** implementar el método de Regula Falsi.
