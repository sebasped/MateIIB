# %% [markdown]
# # Librerías

# %%
import numpy as np #para manejar arreglos
from matplotlib import pyplot as plt #para graficar

plt.rcParams["figure.figsize"] = (10,5) #tamaño de los gráficos: ancho x alto

# %% [markdown]
# # Resolución numérica de ecuaciones diferenciales
# ## ¿Cuál es la idea/objetivo?
#
# ---

# %% [markdown]
# # Método de Euler explícito
#
# ## Definir el método de Euler (misma idea de siempre, primero una función que dé UN SOLO paso, y luego otra que dé muchos pasos usando la anterior).

# %%
# defino el paso
# def paso_euler_explicito(...):
#   x_sig = ...
#   return ...


# defino el método
# def metodo_euler_explicito(...):
#   x = ...
#   t = ...

#   valores_x = np.array([]) #vector vacío para guardar los x
#   valores_x = np.append(...) #agrego el 1er. x que ya lo tengo

#   valores_t = np.array([]) #vector vacío para guardar los t
#   valores_t = np.append(...) #agrego el 1er. t que ya lo tengo

#   for i in range(...):
#     x_sig = ...

#     valores_x = np.append(...) #agrego el x_sig

#     t_sig = t + h #calculo el siguiente t
#     valores_t = np.append(...) #agrego elemento al final del vector

#     t = ...
#     x = ...

#   return ..., ... #devuelvo lo necesario para graficar aproximadamente x(t)

# %% [markdown]
# ## Ejemplo
#
# ### Queremos usar el método de Euler explícito para aproximar $x(2)$ dado por la ecuación diferencial (mejor dicho el PVI):
#
# $$\begin{cases}
# x'(t)&=x(t)\\
# x(0)&=1
# \end{cases}
# $$
#
# ### Apromixar $x(2)$ usando el método de Euler con 5, 10, 50 y 100 pasos. Graficar la función $e^t$ (que es sol. exacta de la ec. dif.) para t entre 0 y 2 junto con las aproximaciones obtenidas por Euler. ¿Qué se observa?

# %%
# Aproximo por Euler explícito la sol. de la ec. dif. que me dan.

# defino la función que le tengo que pasar al método de Euler
# def func(t,x):
#   y = ...
#   return y


# resuelvo y aproximo por Euler explícito
# x0 = ...
# t0 = ...
# tf = ...

# N = ...
# h = ...
# vals_t, vals_x = metodo_euler_explicito(...)


# grafico la aproximación de Euler explícito
# plt.plot(vals_t ,vals_x, '*', label='x(t) por Euler con N={}'.format(N))


# grafico la solución exacta
# vals_t_graf = np.linspace(0,2,10000)
# vals_x_func = np.exp(vals_t_graf)
# plt.plot(vals_t_graf, vals_x_func, label='x(t) verdadera')


#algo de estética
# plt.xlabel('Tiempo t')
# plt.ylabel('x(t)')

# plt.legend() #para mostrar los labels

# %% [markdown]
# ## Ejercicio
#
# ### Consideremos el PVI:
#
# $$
# \begin{cases}
# x'(t)&=t\cos(x(t))\\
# x(0)&=3
# \end{cases}
# $$
#
# 1. ### En papel: calcular el tamaño del paso a priori necesario para estimar $x(2)$ con un error menor a $10^{-3}$ usando el método de Euler. (Mirar error global de Euler de la teórica).
#
# 1. ### Usar el método de Euler explícito para aproximar la solución del PVI con $t$ entre 0 y 2, para el tamaño de paso averiguado en el ítem anterior. Graficar los resultados obtenidos.

# %%
# defino la función
# def func(t,x):
#   y = ...
#   return y


# aproximo la sol. por Euler explícito
# x0 = ...
# t0 = ...
# tf = ...

# Acá va el h que calculé en papel
# h = 1.4*10**(-5)
# h = 10**(-6) #probar este y ver como aumenta MUCHO la cantidad de pasos
# N = int( (tf-t0)/h ) #devuelve parte entera: detalle técnico para que N sea entero y el range no se queje.

# resolver por Euler
# ... = metodo_euler_explicito(...)

# graficar la solución que da Euler
# plt.plot(... ,..., '*', label='x(t) por Euler error menor a 10^(-3)')

# estética para el gráfico
# plt.xlabel('Tiempo t')
# plt.ylabel('x(t)')
# plt.legend()

# print('Cantidad de pasos', N) #¡son muchos! ¿por qué?

# %% [markdown]
# ---
# # Método de Taylor de orden 2
#
# ## Charlar diferencias contra Euler explícito

# %%
# def paso_taylor(x, t, h, f, ft, fx):
#   k = ft(t,x) + fx(t,x)*f(t,x)
#   x_sig = x + h*f(t,x) + 0.5*(h**2)*k
#   return x_sig


# def metodo_taylor(x0, t0, h, f, ft, fx, cant_pasos):
#   x = x0
#   t = t0

#   valores_x = np.array([]) #vector vacío
#   valores_x = np.append(valores_x, x0) #agrego elemento al final

#   valores_t = np.array([])
#   valores_t = np.append(valores_t, t0) #agrego elemento al final

#   for i in range(0,cant_pasos,1):
#     x_sig = paso_taylor(x, t, h, f, ft, fx)

#     valores_x = np.append(valores_x, x_sig) #agrego elemento al final del vector

#     t = t + h
#     valores_t = np.append(valores_t, t) #agrego elemento al final del vector

#     x = x_sig

#   return valores_t, valores_x

# %% [markdown]
# ## Ejemplo Taylor orden 2
#
# $$
# \begin{cases}
# x'(t)&=t\cos(x(t))\\
# x(0)&=3
# \end{cases}
# $$
#
# ### Usar el método de Taylor de orden 2 para aproximar la solución del PVI con $t$ entre 0 y 2. Graficar los resultados obtenidos.

# %%
# def func(t,x):
#   y = t*np.cos(x)
#   return y

# def func_deriv_t(t,x):
#   y = np.sin(x)
#   return y

# def func_deriv_x(t,x):
#   y = (-1)*t*np.sin(x)
#   return y


# x0 = 3
# t0 = 0
# tf = 2
# h = 10**(-3)
# N = int( (tf-t0)/h ) #devuelve parte entera: detalle técnico para que N sea entero y el range no se queje.

# vals_t, vals_x = metodo_taylor(x0, t0, h, func, func_deriv_t, func_deriv_x, N)
# plt.plot(vals_t ,vals_x, '*', label='x(t) por Taylor con paso {}'.format(h))
# plt.xlabel('Tiempo t')
# plt.ylabel('x(t)')
# plt.legend()

# %% [markdown]
# ---
# # Comparar los códigos de `metodo_euler_explicito` y de `metodo_taylor`. ¿Qué diferencias observa?
#
# # Charlar Taylor orden k: virtudes y desventajas.
#
# # ¿Qué tengo que cambiar en el código si quiero hacer Taylor de orden 3?

# %% [markdown]
# ---
# # **Ejercicio:** el 7 de la guía (Euler modificado y Heun).
#
# ## Observación: Heun es Runge-Kutta de orden 2.

# %%
# def paso_heun(x, t, h, f):
#   k1 = f(t,x)
#   k2 = f(t+h, x+h*k1)
#   x_sig = x + 0.5*h*(k1+k2)
#   return x_sig


# def metodo_heun(x0, t0, h, f, cant_pasos):

#   ...

#   return valores_t, valores_x

# %%
# def paso_euler_modificado(...):
#   ...
#   ...
#   return ...

# def metodo_euler_modificado(...):
#   ...
#   ...
#   return ...

# %% [markdown]
# ---
# # **Ejercicio:** el 9 de la guía (Runge-Kutta de orden 4)
#
# ## Charlar diferencias versus Taylor

# %%
# def paso_runge_kutta_4(...):
#   ...
#   return ...


# def metodo_runge_kutta_4(...):
#   ...
#   return ...

# %% [markdown]
# ---
# # Charlar el ejercicio 6 (orden de convergencia de Euler explícito vs. Taylor)
